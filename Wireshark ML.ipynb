# %%
import pandas as pd

# %%
fileLoc = 'C:\\Users\\morgand5\\Data\\captures\\28feb2018.csv'
df=pd.read_csv(fileLoc)

# %%
df
# Out:
#        No.        Time                     Source  \
# 0        1    0.000000            192.168.230.126
# 1        2    0.105970          Raspberr_bd:51:74
# 2        3    0.141063             Cisco_eb:9c:98
# 3        4    0.988279            192.168.230.113
# 4        5    0.995905            192.168.230.126
# 5        6    1.022364            192.168.230.112
# 6        7    1.124755          Raspberr_bd:51:74
# 7        8    1.998276            192.168.230.126
# 8        9    2.023666            192.168.230.112
# 9       10    2.143978             Cisco_eb:9c:98
# 10      11    2.164736          Raspberr_bd:51:74
# 11      12    2.535783            192.168.230.113
# 12      13    2.999944            192.168.230.126
# 13      14    3.123542             Cisco_eb:9c:98
# 14      15    3.204915          Raspberr_bd:51:74
# 15      16    3.277803            192.168.230.108
# 16      17    3.282724            192.168.230.129
# 17      18    3.283827            192.168.230.108
# ...
